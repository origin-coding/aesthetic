# %%
import seaborn as sns
import pandas as pd

# %%
aadb_data = pd.read_csv("../data/aadb.csv")

# %%
aadb_data.describe()
# Out:
#                 dof  balancing_elements  color_harmony       content  \
# count  10000.000000        10000.000000   10000.000000  10000.000000
# mean       0.295100            0.334600       0.425300      0.472400
# std        0.456111            0.471874       0.494413      0.499263
# min        0.000000            0.000000       0.000000      0.000000
# 25%        0.000000            0.000000       0.000000      0.000000
# 50%        0.000000            0.000000       0.000000      0.000000
# 75%        1.000000            1.000000       1.000000      1.000000
# max        1.000000            1.000000       1.000000      1.000000
#
#               light   motion_blur        object    repetition      symmetry  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.411700      0.917800      0.473900      0.198100      0.091500
# std        0.492166      0.274683      0.499343      0.398588      0.288333
# ...

# %%
sns.histplot(aadb_data, x="content", bins=2)
# Out:
# <Axes: xlabel='content', ylabel='Count'>
